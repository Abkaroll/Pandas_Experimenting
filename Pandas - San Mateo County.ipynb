# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.24.2

# %%
df = pd.read_json("https://data.smcgov.org/resource/mb6a-xn89.json")

df.head(5)
# Out:
#    :@computed_region_i2t2_cryp  :@computed_region_uph5_8hpn  \
# 0                        28596                          2.0
# 1                        28588                          4.0
# 2                          319                          6.0
# 3                        28597                         14.0
# 4                        28607                         21.0
#
#    bachelor_s_degree_or_higher       geography geography_type  \
# 0                          3.5        Atherton           Town
# 1                          2.4           Colma           Town
# 2                          2.9     Foster City           City
# 3                          1.8  Portola Valley           Town
# 4                          3.0    Redwood City           City
#
#    high_school_graduate  less_than_high_school_graduate  \
# 0                  12.3                            13.6
# 1                   6.4                             6.3
# 2                   9.7                            11.9
# 3                   0.0                            48.1
# 4                  10.6                            16.4
#
#                                           location_1  \
# 0  {'type': 'Point', 'coordinates': [-122.2, 37.4...
# 1  {'type': 'Point', 'coordinates': [-122.455556,...
# 2  {'type': 'Point', 'coordinates': [-122.266389,...
# 3  {'type': 'Point', 'coordinates': [-122.218611,...
# 4  {'type': 'Point', 'coordinates': [-122.236111,...
#
#    some_college_or_associate_s_degree                     year
# 0                                 2.7  2014-01-01T00:00:00.000
# 1                                10.4  2014-01-01T00:00:00.000
# 2                                 2.0  2014-01-01T00:00:00.000
# 3                                 0.0  2014-01-01T00:00:00.000
# 4                                 6.6  2014-01-01T00:00:00.000

# %%
df.shape
# Out:
# (32, 10)

# %%
df.describe()
# Out:
#        :@computed_region_i2t2_cryp  :@computed_region_uph5_8hpn  \
# count                    32.000000                    30.000000
# mean                  25062.093750                    17.733333
# std                    9502.711577                     9.762466
# min                     312.000000                     1.000000
# 25%                   28587.750000                     9.500000
# 50%                   28595.000000                    18.500000
# 75%                   28604.250000                    25.750000
# max                   28613.000000                    34.000000
#
#        bachelor_s_degree_or_higher  high_school_graduate  \
# count                    32.000000             32.000000
# mean                      2.856250              6.462500
# std                       1.873919              4.693905
# min                       0.000000              0.000000
# 25%                       2.100000              1.925000
# 50%                       3.000000              7.750000
# 75%                       3.600000              9.450000
# max                       9.100000             16.400000
#
#        less_than_high_school_graduate  some_college_or_associate_s_degree
# count                        32.00000                           32.000000
# mean                         17.80000                            5.946875
# std                          19.29944                            4.728430
# min                           0.00000                            0.000000
# 25%                           6.82500                            2.525000
# 50%                          13.90000                            5.500000
# 75%                          20.97500                            8.800000
# max                         100.00000                           18.500000

# %%
df.describe(include = 'all')
# Out:
#         :@computed_region_i2t2_cryp  :@computed_region_uph5_8hpn  \
# count                     32.000000                    30.000000
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   25062.093750                    17.733333
# std                     9502.711577                     9.762466
# min                      312.000000                     1.000000
# 25%                    28587.750000                     9.500000
# 50%                    28595.000000                    18.500000
# 75%                    28604.250000                    25.750000
# max                    28613.000000                    34.000000
#
#         bachelor_s_degree_or_higher geography geography_type  \
# count                     32.000000        32             32
# unique                          NaN        32              3
# top                             NaN  Loma Mar           City
# freq                            NaN         1             15
# mean                       2.856250       NaN            NaN
# std                        1.873919       NaN            NaN
# min                        0.000000       NaN            NaN
# 25%                        2.100000       NaN            NaN
# 50%                        3.000000       NaN            NaN
# 75%                        3.600000       NaN            NaN
# max                        9.100000       NaN            NaN
#
#         high_school_graduate  less_than_high_school_graduate  \
# count              32.000000                        32.00000
# unique                   NaN                             NaN
# top                      NaN                             NaN
# freq                     NaN                             NaN
# mean                6.462500                        17.80000
# std                 4.693905                        19.29944
# min                 0.000000                         0.00000
# 25%                 1.925000                         6.82500
# 50%                 7.750000                        13.90000
# 75%                 9.450000                        20.97500
# max                16.400000                       100.00000
#
#                                                location_1  \
# count                                                  32
# unique                                                 32
# top     {'type': 'Point', 'coordinates': [-122.259722,...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         some_college_or_associate_s_degree                     year
# count                            32.000000                       32
# unique                                 NaN                        1
# top                                    NaN  2014-01-01T00:00:00.000
# freq                                   NaN                       32
# mean                              5.946875                      NaN
# std                               4.728430                      NaN
# min                               0.000000                      NaN
# 25%                               2.525000                      NaN
# 50%                               5.500000                      NaN
# 75%                               8.800000                      NaN
# max                              18.500000                      NaN

# %%
df.mean(axis=0)
# Out:
# :@computed_region_i2t2_cryp           25062.093750
# :@computed_region_uph5_8hpn              17.733333
# bachelor_s_degree_or_higher               2.856250
# high_school_graduate                      6.462500
# less_than_high_school_graduate           17.800000
# some_college_or_associate_s_degree        5.946875
# dtype: float64

# %%
df.median(axis=0)
# Out:
# :@computed_region_i2t2_cryp           28595.00
# :@computed_region_uph5_8hpn              18.50
# bachelor_s_degree_or_higher               3.00
# high_school_graduate                      7.75
# less_than_high_school_graduate           13.90
# some_college_or_associate_s_degree        5.50
# dtype: float64

# %%
df.mode(axis=0)
# Out:
#     :@computed_region_i2t2_cryp  :@computed_region_uph5_8hpn  \
# 0                       28607.0                          1.0
# 1                           NaN                          2.0
# 2                           NaN                          4.0
# 3                           NaN                          5.0
# 4                           NaN                          6.0
# 5                           NaN                          7.0
# 6                           NaN                          8.0
# 7                           NaN                          9.0
# 8                           NaN                         11.0
# 9                           NaN                         12.0
# 10                          NaN                         13.0
# 11                          NaN                         14.0
# 12                          NaN                         15.0
# 13                          NaN                         16.0
# 14                          NaN                         18.0
# 15                          NaN                         19.0
# 16                          NaN                         20.0
# 17                          NaN                         21.0
# 18                          NaN                         22.0
# 19                          NaN                         23.0
# 20                          NaN                         24.0
# 21                          NaN                         25.0
# 22                          NaN                         26.0
# 23                          NaN                         27.0
# 24                          NaN                         28.0
# 25                          NaN                         29.0
# 26                          NaN                         30.0
# 27                          NaN                         31.0
# 28                          NaN                         32.0
# 29                          NaN                         34.0
# 30                          NaN                          NaN
# 31                          NaN                          NaN
#
#     bachelor_s_degree_or_higher               geography geography_type  \
# 0                           0.0                Atherton           City
# 1                           NaN                 Belmont            NaN
# 2                           NaN                Brisbane            NaN
# 3                           NaN               Broadmoor            NaN
# 4                           NaN              Burlingame            NaN
# 5                           NaN                   Colma            NaN
# 6                           NaN               Daly City            NaN
# 7                           NaN          East Palo Alto            NaN
# 8                           NaN              El Granada            NaN
# 9                           NaN      Emerald Lake Hills            NaN
# 10                          NaN             Foster City            NaN
# 11                          NaN           Half Moon Bay            NaN
# 12                          NaN  Highlands-Baywood Park            NaN
# 13                          NaN            Hillsborough            NaN
# 14                          NaN                La Honda            NaN
# 15                          NaN                  Ladera            NaN
# 16                          NaN                Loma Mar            NaN
# 17                          NaN              Menlo Park            NaN
# 18                          NaN                Millbrae            NaN
# 19                          NaN                 Montara            NaN
# 20                          NaN              Moss Beach            NaN
# 21                          NaN         North Fair Oaks            NaN
# 22                          NaN                Pacifica            NaN
# 23                          NaN               Pescadero            NaN
# 24                          NaN          Portola Valley            NaN
# 25                          NaN            Redwood City            NaN
# 26                          NaN               San Bruno            NaN
# 27                          NaN              San Carlos            NaN
# 28                          NaN               San Mateo            NaN
# 29                          NaN     South San Francisco            NaN
# 30                          NaN         West Menlo Park            NaN
# 31                          NaN                Woodside            NaN
#
#     high_school_graduate  less_than_high_school_graduate  \
# 0                    0.0                             0.0
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN
# 5                    NaN                             NaN
# 6                    NaN                             NaN
# 7                    NaN                             NaN
# 8                    NaN                             NaN
# 9                    NaN                             NaN
# 10                   NaN                             NaN
# 11                   NaN                             NaN
# 12                   NaN                             NaN
# 13                   NaN                             NaN
# 14                   NaN                             NaN
# 15                   NaN                             NaN
# 16                   NaN                             NaN
# 17                   NaN                             NaN
# 18                   NaN                             NaN
# 19                   NaN                             NaN
# 20                   NaN                             NaN
# 21                   NaN                             NaN
# 22                   NaN                             NaN
# 23                   NaN                             NaN
# 24                   NaN                             NaN
# 25                   NaN                             NaN
# 26                   NaN                             NaN
# 27                   NaN                             NaN
# 28                   NaN                             NaN
# 29                   NaN                             NaN
# 30                   NaN                             NaN
# 31                   NaN                             NaN
#
#                                            location_1  \
# 0   {'type': 'Point', 'coordinates': [-122.203056,...
# 1   {'type': 'Point', 'coordinates': [-122.2668, 3...
# 2   {'type': 'Point', 'coordinates': [-122.183333,...
# 3   {'type': 'Point', 'coordinates': [-122.419167,...
# 4   {'type': 'Point', 'coordinates': [-122.506389,...
# 5   {'type': 'Point', 'coordinates': [-122.2, 37.4...
# 6   {'type': 'Point', 'coordinates': [-122.291667,...
# 7   {'type': 'Point', 'coordinates': [-122.266389,...
# 8   {'type': 'Point', 'coordinates': [-122.363611,...
# 9   {'type': 'Point', 'coordinates': [-122.3075, 3...
# 10  {'type': 'Point', 'coordinates': [-122.274167,...
# 11  {'type': 'Point', 'coordinates': [-122.236111,...
# 12  {'type': 'Point', 'coordinates': [-122.197222,...
# 13  {'type': 'Point', 'coordinates': [-122.343333,...
# 14  {'type': 'Point', 'coordinates': [-122.266389,...
# 15  {'type': 'Point', 'coordinates': [-122.455556,...
# 16  {'type': 'Point', 'coordinates': [-122.203611,...
# 17  {'type': 'Point', 'coordinates': [-122.356389,...
# 18  {'type': 'Point', 'coordinates': [-122.218611,...
# 19  {'type': 'Point', 'coordinates': [-122.425556,...
# 20  {'type': 'Point', 'coordinates': [-122.478889,...
# 21  {'type': 'Point', 'coordinates': [-122.313056,...
# 22  {'type': 'Point', 'coordinates': [-122.425278,...
# 23  {'type': 'Point', 'coordinates': [-122.485556,...
# 24  {'type': 'Point', 'coordinates': [-122.139722,...
# 25  {'type': 'Point', 'coordinates': [-122.381389,...
# 26  {'type': 'Point', 'coordinates': [-122.512778,...
# 27  {'type': 'Point', 'coordinates': [-122.468333,...
# 28  {'type': 'Point', 'coordinates': [-122.473333,...
# 29  {'type': 'Point', 'coordinates': [-122.401389,...
# 30  {'type': 'Point', 'coordinates': [-122.436944,...
# 31  {'type': 'Point', 'coordinates': [-122.259722,...
#
#     some_college_or_associate_s_degree                     year
# 0                                  0.0  2014-01-01T00:00:00.000
# 1                                  NaN                      NaN
# 2                                  NaN                      NaN
# 3                                  NaN                      NaN
# 4                                  NaN                      NaN
# 5                                  NaN                      NaN
# 6                                  NaN                      NaN
# 7                                  NaN                      NaN
# 8                                  NaN                      NaN
# 9                                  NaN                      NaN
# 10                                 NaN                      NaN
# 11                                 NaN                      NaN
# 12                                 NaN                      NaN
# 13                                 NaN                      NaN
# 14                                 NaN                      NaN
# 15                                 NaN                      NaN
# 16                                 NaN                      NaN
# 17                                 NaN                      NaN
# 18                                 NaN                      NaN
# 19                                 NaN                      NaN
# 20                                 NaN                      NaN
# 21                                 NaN                      NaN
# 22                                 NaN                      NaN
# 23                                 NaN                      NaN
# 24                                 NaN                      NaN
# 25                                 NaN                      NaN
# 26                                 NaN                      NaN
# 27                                 NaN                      NaN
# 28                                 NaN                      NaN
# 29                                 NaN                      NaN
# 30                                 NaN                      NaN
# 31                                 NaN                      NaN

# %%
df.count()
# Out:
# :@computed_region_i2t2_cryp           32
# :@computed_region_uph5_8hpn           30
# bachelor_s_degree_or_higher           32
# geography                             32
# geography_type                        32
# high_school_graduate                  32
# less_than_high_school_graduate        32
# location_1                            32
# some_college_or_associate_s_degree    32
# year                                  32
# dtype: int64

# %%
df.bachelor_s_degree_or_higher.mean()
# Out:
# 2.8562500000000006

# %%
df.geography.count()
# Out:
# 32

# %%
def mapGeography(x):
    if x == "City":
        return 1
    else:
        return 0

df['geography_mapped_value'] = df.geography_type.apply(mapGeography)

df.geography_mapped_value.value_counts()
# Out:
# 0    17
# 1    15
# Name: geography_mapped_value, dtype: int64
